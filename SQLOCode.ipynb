-- %% [markdown]
-- # [sauniversities]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [sauniversities]    Script Date: 2020/12/07 14:38:03 ******/
CREATE DATABASE [sauniversities]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'sauniversities', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.AQEELMAJAL\MSSQL\DATA\sauniversities.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'sauniversities_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.AQEELMAJAL\MSSQL\DATA\sauniversities_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [sauniversities] SET COMPATIBILITY_LEVEL = 130
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [sauniversities].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [sauniversities] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [sauniversities] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [sauniversities] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [sauniversities] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [sauniversities] SET ARITHABORT OFF 
GO
ALTER DATABASE [sauniversities] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [sauniversities] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [sauniversities] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [sauniversities] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [sauniversities] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [sauniversities] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [sauniversities] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [sauniversities] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [sauniversities] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [sauniversities] SET  DISABLE_BROKER 
GO
ALTER DATABASE [sauniversities] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [sauniversities] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [sauniversities] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [sauniversities] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [sauniversities] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [sauniversities] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [sauniversities] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [sauniversities] SET RECOVERY FULL 
GO
ALTER DATABASE [sauniversities] SET  MULTI_USER 
GO
ALTER DATABASE [sauniversities] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [sauniversities] SET DB_CHAINING OFF 
GO
ALTER DATABASE [sauniversities] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [sauniversities] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [sauniversities] SET DELAYED_DURABILITY = DISABLED 
GO
EXEC sys.sp_db_vardecimal_storage_format N'sauniversities', N'ON'
GO
ALTER DATABASE [sauniversities] SET QUERY_STORE = OFF
GO
USE [sauniversities]
GO
ALTER DATABASE SCOPED CONFIGURATION SET LEGACY_CARDINALITY_ESTIMATION = OFF;
GO
ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 0;
GO
ALTER DATABASE SCOPED CONFIGURATION SET PARAMETER_SNIFFING = ON;
GO
ALTER DATABASE SCOPED CONFIGURATION SET QUERY_OPTIMIZER_HOTFIXES = OFF;
GO

-- %% [markdown]
-- # [dbo].[Cities]

-- %%
USE [sauniversities]
GO

-- %%
/****** Object:  Table [dbo].[Cities]    Script Date: 2020/12/07 14:38:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Cities](
	[city_id] [varchar](50) NULL,
	[city_name] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[cityuniversities]

-- %%
/****** Object:  Table [dbo].[cityuniversities]    Script Date: 2020/12/07 14:38:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[cityuniversities](
	[university_id] [varchar](50) NULL,
	[city_id] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[universities]

-- %%
/****** Object:  Table [dbo].[universities]    Script Date: 2020/12/07 14:38:04 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[universities](
	[universities_id] [varchar](50) NULL,
	[universities_name] [varchar](50) NULL
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [sauniversities]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [sauniversities] SET  READ_WRITE 
GO
